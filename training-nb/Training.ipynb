# %%
from fastai.vision import *
from fastai.metrics import error_rate
from pathlib import Path
from glob2 import glob
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import os
import zipfile as zf
import shutil
import re
import seaborn as sns

# %%
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))
# Out:
# ['paper', '.DS_Store', 'metal', 'cardboard', 'trash', 'glass', 'plastic']

# %%
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    ## train indices
    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.5*n))

    ## temp
    remain = list(set(full_set)-set(train))

    ## separate remaining into validation and test
    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

## gets file names for a particular type of trash, given indices
    ## input: waste category and indices
    ## output: file names 
def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

## moves group of source files to another folder
    ## input: list of source files and destination folder
    ## no output
def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %%
## paths will be train/cardboard, train/glass, etc...
subsets = ['train','valid']
waste_types = ['cardboard','glass','metal','paper','plastic','trash']

## create destination folders for data subset and waste type
for subset in subsets:
    for waste_type in waste_types:
        folder = os.path.join('data',subset,waste_type)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
if not os.path.exists(os.path.join('data','test')):
    os.makedirs(os.path.join('data','test'))
            
## move files to destination folders for each waste type
for waste_type in waste_types:
    source_folder = os.path.join('dataset-resized',waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    ## move source files to train
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = "data/train/"+waste_type
    move_files(train_source_files,train_dest)
    
    ## move source files to valid
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = "data/valid/"+waste_type
    move_files(valid_source_files,valid_dest)
    
    ## move source files to test
    test_names = get_names(waste_type,test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    ## I use data/test here because the images can be mixed up
    move_files(test_source_files,"data/test")

# %%
path = Path(os.getcwd())/"data"
path
# Out:
# PosixPath('/Users/eric/Untitled Folder/data')

# %%
tfms = get_transforms(do_flip=True,flip_vert=True)
data = ImageDataBunch.from_folder(path,test="test",ds_tfms=tfms,bs=4)

# %%
print(data)
print(data.classes)
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/eric/Untitled Folder/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/eric/Untitled Folder/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /Users/eric/Untitled Folder/data
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
learn = create_cnn(data,models.resnet34,metrics=error_rate)
# Out:
# /usr/local/lib/python3.7/site-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /Users/eric/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=6, bias=True)
#   )
# )

# %%
learn.lr_find(start_lr=1e-6,end_lr=1e1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='315', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       26.35% [83/315 06:50<19:08 8.0851]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(20,max_lr=6.13e-03)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.723042</td>
#       <td>0.845857</td>
#       <td>0.288889</td>
#       <td>38:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.424131</td>
#       <td>0.680642</td>
#       <td>0.231746</td>
#       <td>35:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.515782</td>
#       <td>1.027354</td>
#       <td>0.339683</td>
#       <td>32:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.956758</td>
#       <td>1.253337</td>
#       <td>0.414286</td>
#       <td>35:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.140414</td>
#       <td>1.204919</td>
#       <td>0.430159</td>
#       <td>8:38:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.894592</td>
#       <td>1.579770</td>
#       <td>0.546032</td>
#       <td>34:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.865854</td>
#       <td>1.152412</td>
#       <td>0.417460</td>
#       <td>32:40</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.557373</td>
#       <td>1.173293</td>
#       <td>0.482540</td>
#       <td>1:05:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.532241</td>
#       <td>0.971174</td>
#       <td>0.358730</td>
#       <td>1:45:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.414597</td>
#       <td>1.008345</td>
#       <td>0.379365</td>
#       <td>31:29</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.357466</td>
#       <td>1.062057</td>
#       <td>0.422222</td>
#       <td>30:59</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.347064</td>
#       <td>0.938457</td>
#       <td>0.346032</td>
#       <td>43:35</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.265423</td>
#       <td>0.907842</td>
#       <td>0.344444</td>
#       <td>31:50</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.177693</td>
#       <td>0.786621</td>
#       <td>0.277778</td>
#       <td>31:33</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.102034</td>
#       <td>0.780577</td>
#       <td>0.296825</td>
#       <td>1:57:13</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.047913</td>
#       <td>0.758822</td>
#       <td>0.274603</td>
#       <td>1:05:43</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.957143</td>
#       <td>0.696505</td>
#       <td>0.249206</td>
#       <td>28:22</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.948659</td>
#       <td>0.710171</td>
#       <td>0.220635</td>
#       <td>30:29</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.969818</td>
#       <td>0.679322</td>
#       <td>0.222222</td>
#       <td>32:38</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.955261</td>
#       <td>0.645162</td>
#       <td>0.215873</td>
#       <td>28:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('glass', 'metal', 19),
#  ('glass', 'plastic', 15),
#  ('metal', 'glass', 12),
#  ('plastic', 'glass', 9),
#  ('plastic', 'metal', 9),
#  ('cardboard', 'paper', 8),
#  ('trash', 'plastic', 8),
#  ('paper', 'metal', 7),
#  ('paper', 'trash', 6),
#  ('metal', 'plastic', 5),
#  ('cardboard', 'metal', 4),
#  ('glass', 'trash', 4),
#  ('paper', 'cardboard', 4),
#  ('plastic', 'paper', 4),
#  ('trash', 'paper', 4),
#  ('cardboard', 'glass', 3),
#  ('paper', 'plastic', 3),
#  ('trash', 'glass', 3),
#  ('trash', 'cardboard', 2),
#  ('trash', 'metal', 2)]

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %%
preds[0]
# Out:
# tensor([[1.2611e-01, 4.7440e-01, 1.5116e-01, 4.4354e-02, 1.4346e-01, 6.0512e-02],
#         [1.0933e-04, 1.2762e-02, 9.7738e-01, 3.1285e-04, 9.3876e-03, 5.0547e-05],
#         [1.8253e-03, 3.5082e-02, 7.4194e-03, 1.7223e-03, 9.5205e-01, 1.9020e-03],
#         ...,
#         [1.8861e-02, 3.8376e-03, 1.6669e-03, 8.8011e-01, 5.0399e-02, 4.5127e-02],
#         [1.3128e-02, 2.4361e-02, 2.4900e-02, 5.7315e-01, 1.5177e-01, 2.1269e-01],
#         [7.7058e-04, 3.8563e-01, 1.7388e-01, 1.0469e-04, 4.3947e-01, 1.4239e-04]])

# %%
max_idxs = np.asarray(np.argmax(preds[0],axis=1))

# %%
yhat = []
for max_idx in max_idxs:
    yhat.append(data.classes[max_idx])
yhat
# Out:
# ['glass',
#  'metal',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'metal',
#  'paper',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'plastic',
#  'metal',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'metal',
#  'trash',
#  'plastic',
#  'glass',
#  'metal',
#  'metal',
#  'trash',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'trash',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'paper',
#  'trash',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'paper',
#  'metal',
#  'metal',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'metal',
#  'trash',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'paper',
#  'metal',
#  'metal',
#  'plastic',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'metal',
#  'cardboard',
#  'metal',
#  'trash',
#  'glass',
#  'metal',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'metal',
#  'paper',
#  'trash',
#  'metal',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'trash',
#  'metal',
#  'metal',
#  'trash',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'metal',
#  'plastic',
#  'trash',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'metal',
#  'trash',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'trash',
#  'cardboard',
#  'glass',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'metal',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'metal',
#  'metal',
#  'metal',
#  'glass',
#  'plastic',
#  'paper',
#  'trash',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'metal',
#  'metal',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'metal',
#  'metal',
#  'cardboard',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'metal',
#  'plastic',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'trash',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'metal',
#  'paper',
#  'paper',
#  'metal',
#  'cardboard',
#  'glass',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'glass',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'paper',
#  'metal',
#  'metal',
#  'metal',
#  'paper',
#  'trash',
#  'paper',
#  'paper',
#  'trash',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'metal',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'trash',
#  'metal',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'trash',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'plastic',
#  'cardboard',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'trash',
#  'glass',
#  'paper',
#  'trash',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'metal',
#  'metal',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'plastic']

# %%
y = []

## convert POSIX paths to string first
for label_path in data.test_ds.items:
    y.append(str(label_path))
    
## then extract waste type from file path
pattern = re.compile("([a-z]+)[0-9]+")
for i in range(len(y)):
    y[i] = pattern.search(y[i]).group(1)

# %%
## predicted values
print(yhat[0:5])
## actual values
print(y[0:5])
# Out:
# ['glass', 'metal', 'plastic', 'glass', 'paper']
# ['cardboard', 'metal', 'plastic', 'trash', 'plastic']

# %%
cm = confusion_matrix(y,yhat)
print(cm)
# Out:
# [[ 92   2   5   2   0   0]
#  [  0  84  21   0  19   2]
#  [  1  16  72   1  10   3]
#  [  1   1   7 137   0   3]
#  [  0   9   6   6  97   3]
#  [  2   5   3   9   6  10]]

# %%
waste_types = ['cardboard','glass','metal','paper','plastic','trash']
df_cm = pd.DataFrame(cm,waste_types,waste_types)

plt.figure(figsize=(10,8))
sns.heatmap(df_cm,annot=True,fmt="d",cmap="YlGnBu")

# %%
correct = 0

for r in range(len(cm)):
    for c in range(len(cm)):
        if (r==c):
            correct += cm[r,c]
accuracy = correct/sum(sum(cm))
accuracy
# Out:
# 0.7748031496062993

# %%
learn.export()

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/eric/Untitled Folder/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/eric/Untitled Folder/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /Users/eric/Untitled Folder/data
