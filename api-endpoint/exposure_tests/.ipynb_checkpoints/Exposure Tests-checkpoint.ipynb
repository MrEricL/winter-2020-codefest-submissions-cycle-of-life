# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

def check_exposure(loc):
    img = cv.imread(loc,0)
    hist,bins = np.histogram(img.flatten(),256,[0,256])
    cdf = hist.cumsum()
    cdf_25 = cdf[len(cdf)//4]/cdf[-1] * 100
    cdf_75 = cdf[3*len(cdf)//4]/cdf[-1] * 100
    exposure = None
    if cdf_25 >= 60:
        if cdf_25 >= 80:
            exposure = (1, "very underexposed")
        else:
            exposure = (1, "a little underexposed")
    elif cdf_75 <= 30:
        if cdf_75 <= 20:
            exposure = (2, "very overexposed")
        else:
            exposure = (2, "a little underexposed")
    else:
        exposure = (0, "")
    
    return exposure
        
        

img = cv.imread('wine.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
#print(cdf)
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]

print(x,y, z/x, y/x )
plt.imshow(img)
plt.show()

print(check_exposure("wine.jpg"))
# Out:
# 540000 508106 0.42595 0.940937037037037
# (0, '')

# %%
img = cv.imread('over.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
plt.imshow(img)
plt.show()
print(x,y, z/x, y/x )
print(check_exposure("over.jpg"))
# Out:
# 797526 28467 0.0 0.035694134109734356
# (2, 'very overexposed')

# %%
img = cv.imread('under.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
plt.imshow(img)
plt.show()
print(x,y, z/x, y/x )
print(check_exposure("under.jpg"))
# Out:
# 1707200 1629949 0.8541078959700094 0.9547498828491097
# (1, 'very underexposed')

# %%
img = cv.imread('under2.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
plt.imshow(img)
plt.show()
print(x,y, z/x, y/x )

print(check_exposure("over2.jpg"))
# Out:
# 1440000 1273263 0.6036847222222222 0.8842104166666667
# (0, '')

# %%
img = cv.imread('under3.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
plt.imshow(img)
plt.show()
print(x,y, z/x, y/x )

print(check_exposure("under3.jpg"))
# Out:
# 175104 167546 0.7037474872076024 0.9568370796783626
# (1, 'a little underexposed')

# %%
img = cv.imread('over2.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
plt.imshow(img)
plt.show()
print(x,y, z/x, y/x )

print(check_exposure("over2.jpg"))
# Out:
# 2170800 1697120 0.22524691358024693 0.7817947300534365
# (0, '')

# %%
img = cv.imread('over3.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
plt.imshow(img)
plt.show()
print(x,y, z/x, y/x )

print(check_exposure("over3.jpg"))
# Out:
# 3983616 583570 0.0015383008804061436 0.14649253341687551
# (2, 'very overexposed')

# %%
img = cv.imread('ok.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
plt.imshow(img)
plt.show()
print(x,y, z/x, y/x )

print(check_exposure("ok.jpg"))
# Out:
# 471552 427937 0.16217935667752442 0.9075075495385451
# (0, '')
