# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

def check_exposure(loc):
    img = cv.imread(loc,0)
    hist,bins = np.histogram(img.flatten(),256,[0,256])
    cdf = hist.cumsum()
    cdf_25 = cdf[len(cdf)//4]/cdf[-1] * 100
    cdf_75 = cdf[3*len(cdf)//4]/cdf[-1] * 100
    exposure = None
    if cdf_25 >= 60:
        if cdf_25 >= 80:
            exposure = (1, "very underexposed")
        else:
            exposure = (1, "a little underexposed")
    elif cdf_75 <= 30:
        if cdf_75 <= 20:
            exposure = (2, "very overexposed")
        else:
            exposure = (2, "a little underexposed")
    else:
        exposure = (0, "")
    
    return exposure
        
        

img = cv.imread('wine.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
#print(cdf)
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 540000 508106 0.940937037037037 0.42595

# %%
img = cv.imread('over.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 797526 28467 0.035694134109734356 0.0

# %%
img = cv.imread('imgs/test.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 122500 9699 0.07917551020408163 0.0017061224489795918

# %%
img = cv.imread('under.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 1707200 1629949 0.9547498828491097 0.8541078959700094

# %%
img = cv.imread('under2.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 1440000 1273263 0.8842104166666667 0.6036847222222222

# %%
img = cv.imread('under3.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 175104 167546 0.9568370796783626 0.7037474872076024

# %%
img = cv.imread('over2.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 2170800 1697120 0.7817947300534365 0.22524691358024693

# %%
img = cv.imread('wine.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)

x = cdf_normalized[-1]
y = cdf_normalized[3*len(cdf)//4]
z = cdf_normalized[len(cdf_normalized)//4]
print(x,y, y/x, z/x)
# Out:
# 540000 508106 0.940937037037037 0.42595
# 7947.0 7477.626633333333 0.940937037037037 0.42595

# %%
img = cv.imread('over3.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 3983616 583570 0.14649253341687551 0.0015383008804061436

# %%
img = cv.imread('ok.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
x = cdf[-1]
y = cdf[3*len(cdf)//4]
z = cdf[len(cdf)//4]
print(x,y, y/x, z/x)
# Out:
# 471552 427937 0.9075075495385451 0.16217935667752442

# %%
print(check_exposure("over.jpg"))
print(check_exposure("over2.jpg"))
print(check_exposure("over3.jpg"))
print(check_exposure("under.jpg"))
print(check_exposure("under2.jpg"))
print(check_exposure("under3.jpg"))
print(check_exposure("ok.jpg"))
print(check_exposure("wine.jpg"))
# Out:
# (2, 'very overexposed')
# (0, '')
# (2, 'very overexposed')
# (1, 'very underexposed')
# (1, 'a little underexposed')
# (1, 'a little underexposed')
# (0, '')
# (0, '')
